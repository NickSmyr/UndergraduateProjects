# %%
import result_transformation as rt

# %%
our_results_using_rules = """{'Abbr-macro-f1': macro-f1: 0.9371,
 'Abbr-micro-f1': micro-f1: 0.9371,
 'Aspect-macro-f1': macro-f1: 0.9855,
 'Aspect-micro-f1': micro-f1: 0.9866,
 'Case-macro-f1': macro-f1: 0.9684,
 'Case-micro-f1': micro-f1: 0.9767,
 'Definite-macro-f1': macro-f1: 1.0000,
 'Definite-micro-f1': micro-f1: 1.0000,
 'Degree-macro-f1': macro-f1: 0.4904,
 'Degree-micro-f1': micro-f1: 0.9189,
 'Foreign-macro-f1': macro-f1: 0.8761,
 'Foreign-micro-f1': micro-f1: 0.8761,
 'Gender-macro-f1': macro-f1: 0.9775,
 'Gender-micro-f1': micro-f1: 0.9822,
 'Mood-macro-f1': macro-f1: 0.8315,
 'Mood-micro-f1': micro-f1: 0.9940,
 'NumType-macro-f1': macro-f1: 0.9437,
 'NumType-micro-f1': micro-f1: 0.9584,
 'Number-macro-f1': macro-f1: 0.9945,
 'Number-micro-f1': micro-f1: 0.9945,
 'Person-macro-f1': macro-f1: 0.9972,
 'Person-micro-f1': micro-f1: 0.9961,
 'Poss-macro-f1': macro-f1: 0.9802,
 'Poss-micro-f1': micro-f1: 0.9802,
 'PronType-macro-f1': macro-f1: 0.9735,
 'PronType-micro-f1': micro-f1: 0.9972,
 'Tense-macro-f1': macro-f1: 0.9957,
 'Tense-micro-f1': micro-f1: 0.9959,
 'VerbForm-macro-f1': macro-f1: 0.9327,
 'VerbForm-micro-f1': micro-f1: 0.9939,
 'Voice-macro-f1': macro-f1: 0.9572,
 'Voice-micro-f1': micro-f1: 0.9618,
 'upos-macro-f1': macro-f1: 0.9637,
 'upos-micro-f1': micro-f1: 0.9816}"""

interleaving_results = """{'Abbr-macro-f1': macro-f1: 0.9143,
 'Abbr-micro-f1': micro-f1: 0.9143,
 'Aspect-macro-f1': macro-f1: 0.9808,
 'Aspect-micro-f1': micro-f1: 0.9818,
 'Case-macro-f1': macro-f1: 0.9617,
 'Case-micro-f1': micro-f1: 0.9753,
 'Definite-macro-f1': macro-f1: 1.0000,
 'Definite-micro-f1': micro-f1: 1.0000,
 'Degree-macro-f1': macro-f1: 0.4904,
 'Degree-micro-f1': micro-f1: 0.9189,
 'Foreign-macro-f1': macro-f1: 0.8761,
 'Foreign-micro-f1': micro-f1: 0.8761,
 'Gender-macro-f1': macro-f1: 0.9733,
 'Gender-micro-f1': micro-f1: 0.9787,
 'Mood-macro-f1': macro-f1: 0.9428,
 'Mood-micro-f1': micro-f1: 0.9958,
 'NumType-macro-f1': macro-f1: 0.8719,
 'NumType-micro-f1': micro-f1: 0.9292,
 'Number-macro-f1': macro-f1: 0.9915,
 'Number-micro-f1': micro-f1: 0.9923,
 'Person-macro-f1': macro-f1: 0.9968,
 'Person-micro-f1': micro-f1: 0.9952,
 'Poss-macro-f1': macro-f1: 0.9849,
 'Poss-micro-f1': micro-f1: 0.9849,
 'PronType-macro-f1': macro-f1: 0.9470,
 'PronType-micro-f1': micro-f1: 0.9955,
 'Tense-macro-f1': macro-f1: 0.9948,
 'Tense-micro-f1': micro-f1: 0.9948,
 'VerbForm-macro-f1': macro-f1: 0.9325,
 'VerbForm-micro-f1': micro-f1: 0.9931,
 'Voice-macro-f1': macro-f1: 0.9334,
 'Voice-micro-f1': micro-f1: 0.9410,
 'upos-macro-f1': macro-f1: 0.9645,
 'upos-micro-f1': micro-f1: 0.9809}
"""

oversampling_results = """{'Abbr-macro-f1': macro-f1: 0.9231,
 'Abbr-micro-f1': micro-f1: 0.9231,
 'Aspect-macro-f1': macro-f1: 0.9872,
 'Aspect-micro-f1': micro-f1: 0.9879,
 'Case-macro-f1': macro-f1: 0.9872,
 'Case-micro-f1': micro-f1: 0.9784,
 'Definite-macro-f1': macro-f1: 0.9998,
 'Definite-micro-f1': micro-f1: 0.9997,
 'Degree-macro-f1': macro-f1: 0.7979,
 'Degree-micro-f1': micro-f1: 0.9391,
 'Foreign-macro-f1': macro-f1: 0.8559,
 'Foreign-micro-f1': micro-f1: 0.8559,
 'Gender-macro-f1': macro-f1: 0.9717,
 'Gender-micro-f1': micro-f1: 0.9768,
 'Mood-macro-f1': macro-f1: 0.8312,
 'Mood-micro-f1': micro-f1: 0.9935,
 'NumType-macro-f1': macro-f1: 0.8747,
 'NumType-micro-f1': micro-f1: 0.9389,
 'Number-macro-f1': macro-f1: 0.9925,
 'Number-micro-f1': micro-f1: 0.9927,
 'Person-macro-f1': macro-f1: 0.9952,
 'Person-micro-f1': micro-f1: 0.9945,
 'Poss-macro-f1': macro-f1: 0.9800,
 'Poss-micro-f1': micro-f1: 0.9800,
 'PronType-macro-f1': macro-f1: 0.9576,
 'PronType-micro-f1': micro-f1: 0.9955,
 'Tense-macro-f1': macro-f1: 0.9961,
 'Tense-micro-f1': micro-f1: 0.9959,
 'VerbForm-macro-f1': macro-f1: 0.9621,
 'VerbForm-micro-f1': micro-f1: 0.9952,
 'Voice-macro-f1': macro-f1: 0.9648,
 'Voice-micro-f1': micro-f1: 0.9680,
 'upos-macro-f1': macro-f1: 0.9623,
 'upos-micro-f1': micro-f1: 0.9799}
"""

# %%
f1_mic,f1_mac,labels= rt.get_final_results_seperated_our_type_mtask(our_results_using_rules,getLabels=True)

f1_interleaving_mic, f1_interleaving_mac = rt.get_final_results_seperated_our_type_mtask(interleaving_results)

f1_oversampling_mic ,f1_oversampling_mac= rt.get_final_results_seperated_our_type_mtask(oversampling_results)

# %%
# micro
rt.plot([f1_mic, f1_interleaving_mic,f1_oversampling_mic], ['1','2','3'], labels=labels, 
        saved_path = 'imgs/micros_multi', figsize=(25,10),fontsize_label=23,fontsize_per=10)

# %%
# macro
rt.plot([f1_mac, f1_interleaving_mac,f1_oversampling_mac], ['1','2','3'], labels=labels, 
        saved_path = 'imgs/macros_multi', figsize=(25,10),fontsize_label=23,fontsize_per=10)

# %%
# 'upos-macro-f1': macro-f1: 0.9637,
#  'upos-micro-f1': micro-f1: 0.9816}

# 'ner_macro-f1': macro-f1: 0.8517,
#  'ner_micro-f1': micro-f1: 0.9049,
#  'nerud': score: 1.8161,
#  'upos-macro-f1': macro-f1: 0.9645,
#  'upos-micro-f1': micro-f1: 0.9809}



#  'ner_macro-f1': macro-f1: 0.7331,
#  'ner_micro-f1': micro-f1: 0.8479,
#  'nerud': score: 1.6954,
#  'upos-macro-f1': macro-f1: 0.9623,
#  'upos-micro-f1': micro-f1: 0.9799}


labels = ['ner_macro_f1','ner_micro_f1','upos_macro_f1','upos_micro_f1']
separated = [0.83,0.96,0.97,0.99]
interleaving = [0.86,0.91,0.97,0.99]
oversampling = [0.74,0.85,0.97,0.98]
rt.plot([separated, interleaving, oversampling], 
        ['seperated','interleaving','oversampling'], 
        labels = labels, 
        saved_path = 'imgs/all_multi', figsize=(25,10),fontsize_label=23,fontsize_per=20)

# %%
no_oversampling = """
{'Abbr-macro-f1': macro-f1: 0.9595,
 'Abbr-micro-f1': micro-f1: 0.9595,
 'Aspect-macro-f1': macro-f1: 0.9865,
 'Aspect-micro-f1': micro-f1: 0.9874,
 'Case-macro-f1': macro-f1: 0.9351,
 'Case-micro-f1': micro-f1: 0.9742,
 'Definite-macro-f1': macro-f1: 0.9998,
 'Definite-micro-f1': micro-f1: 0.9997,
 'Degree-macro-f1': macro-f1: 0.4854,
 'Degree-micro-f1': micro-f1: 0.9091,
 'Foreign-macro-f1': macro-f1: 0.9547,
 'Foreign-micro-f1': micro-f1: 0.9547,
 'Gender-macro-f1': macro-f1: 0.9717,
 'Gender-micro-f1': micro-f1: 0.9774,
 'Mood-macro-f1': macro-f1: 0.6641,
 'Mood-micro-f1': micro-f1: 0.9912,
 'NumType-macro-f1': macro-f1: 0.6932,
 'NumType-micro-f1': micro-f1: 0.8946,
 'Number-macro-f1': macro-f1: 0.9933,
 'Number-micro-f1': micro-f1: 0.9931,
 'Person-macro-f1': macro-f1: 0.9961,
 'Person-micro-f1': micro-f1: 0.9952,
 'Poss-macro-f1': macro-f1: 0.9754,
 'Poss-micro-f1': micro-f1: 0.9754,
 'PronType-macro-f1': macro-f1: 0.9321,
 'PronType-micro-f1': micro-f1: 0.9953,
 'Tense-macro-f1': macro-f1: 0.9957,
 'Tense-micro-f1': micro-f1: 0.9953,
 'VerbForm-macro-f1': macro-f1: 0.9487,
 'VerbForm-micro-f1': micro-f1: 0.9948,
 'Voice-macro-f1': macro-f1: 0.9536,
 'Voice-micro-f1': micro-f1: 0.9584,
 'total-acc': acc: 0.9951,
 'upos-macro-f1': macro-f1: 0.9669,
 'upos-micro-f1': micro-f1: 0.9822}
 """

oversampling_1 = """
{'Abbr-macro-f1': macro-f1: 0.9595,
 'Abbr-micro-f1': micro-f1: 0.9595,
 'Aspect-macro-f1': macro-f1: 0.9813,
 'Aspect-micro-f1': micro-f1: 0.9830,
 'Case-macro-f1': macro-f1: 0.7814,
 'Case-micro-f1': micro-f1: 0.9766,
 'Definite-macro-f1': macro-f1: 0.9998,
 'Definite-micro-f1': micro-f1: 0.9997,
 'Degree-macro-f1': macro-f1: 0.5657,
 'Degree-micro-f1': micro-f1: 0.8727,
 'Foreign-macro-f1': macro-f1: 0.8186,
 'Foreign-micro-f1': micro-f1: 0.8186,
 'Gender-macro-f1': macro-f1: 0.9747,
 'Gender-micro-f1': micro-f1: 0.9796,
 'Mood-macro-f1': macro-f1: 0.9727,
 'Mood-micro-f1': micro-f1: 0.9977,
 'NumType-macro-f1': macro-f1: 0.7063,
 'NumType-micro-f1': micro-f1: 0.9389,
 'Number-macro-f1': macro-f1: 0.9937,
 'Number-micro-f1': micro-f1: 0.9939,
 'Person-macro-f1': macro-f1: 0.9964,
 'Person-micro-f1': micro-f1: 0.9958,
 'Poss-macro-f1': macro-f1: 0.9659,
 'Poss-micro-f1': micro-f1: 0.9659,
 'PronType-macro-f1': macro-f1: 0.8949,
 'PronType-micro-f1': micro-f1: 0.9946,
 'Tense-macro-f1': macro-f1: 0.9961,
 'Tense-micro-f1': micro-f1: 0.9959,
 'VerbForm-macro-f1': macro-f1: 0.8842,
 'VerbForm-micro-f1': micro-f1: 0.9917,
 'Voice-macro-f1': macro-f1: 0.9474,
 'Voice-micro-f1': micro-f1: 0.9540,
 'total-acc': acc: 0.9948,
 'upos-macro-f1': macro-f1: 0.9610,
 'upos-micro-f1': micro-f1: 0.9804}

"""

oversampling_2 = """
{'Abbr-macro-f1': macro-f1: 0.9664,
 'Abbr-micro-f1': micro-f1: 0.9664,
 'Aspect-macro-f1': macro-f1: 0.9852,
 'Aspect-micro-f1': micro-f1: 0.9861,
 'Case-macro-f1': macro-f1: 0.9654,
 'Case-micro-f1': micro-f1: 0.9787,
 'Definite-macro-f1': macro-f1: 1.0000,
 'Definite-micro-f1': micro-f1: 1.0000,
 'Degree-macro-f1': macro-f1: 0.7629,
 'Degree-micro-f1': micro-f1: 0.9381,
 'Foreign-macro-f1': macro-f1: 0.8811,
 'Foreign-micro-f1': micro-f1: 0.8811,
 'Gender-macro-f1': macro-f1: 0.9769,
 'Gender-micro-f1': micro-f1: 0.9811,
 'Mood-macro-f1': macro-f1: 0.9104,
 'Mood-micro-f1': micro-f1: 0.9958,
 'NumType-macro-f1': macro-f1: 0.7022,
 'NumType-micro-f1': micro-f1: 0.9252,
 'Number-macro-f1': macro-f1: 0.9939,
 'Number-micro-f1': micro-f1: 0.9940,
 'Person-macro-f1': macro-f1: 0.9970,
 'Person-micro-f1': micro-f1: 0.9958,
 'Poss-macro-f1': macro-f1: 0.9800,
 'Poss-micro-f1': micro-f1: 0.9800,
 'PronType-macro-f1': macro-f1: 0.9320,
 'PronType-micro-f1': micro-f1: 0.9951,
 'Tense-macro-f1': macro-f1: 0.9957,
 'Tense-micro-f1': micro-f1: 0.9953,
 'VerbForm-macro-f1': macro-f1: 0.9487,
 'VerbForm-micro-f1': micro-f1: 0.9948,
 'Voice-macro-f1': macro-f1: 0.9555,
 'Voice-micro-f1': micro-f1: 0.9601,
 'total-acc': acc: 0.9952,
 'upos-macro-f1': macro-f1: 0.9645,
 'upos-micro-f1': micro-f1: 0.9806}
"""

# %%
texts = [no_oversampling, oversampling_1, oversampling_2 ]
m_labels = ["no_oversampling" , "oversampling_1", "oversampling_2"]

# %%
import re
pat = "(?:\w*)-(?:macro).*(\d.\d\d\d\d)"
pattern1 = re.compile(pat)
pattern1.findall(no_oversampling)
labels_pat = "(\w*)-(?:macro).*(?:\d.\d\d\d\d)"
pattern2 = re.compile(labels_pat)
labels = pattern2.findall(no_oversampling)
pattern2.findall(no_oversampling) , pattern2.findall(oversampling_2)
# Out:
# (['Abbr',
#   'Aspect',
#   'Case',
#   'Definite',
#   'Degree',
#   'Foreign',
#   'Gender',
#   'Mood',
#   'NumType',
#   'Number',
#   'Person',
#   'Poss',
#   'PronType',
#   'Tense',
#   'VerbForm',
#   'Voice',
#   'upos'],
#  ['Abbr',
#   'Aspect',
#   'Case',
#   'Definite',
#   'Degree',
#   'Foreign',
#   'Gender',
#   'Mood',
#   'NumType',
#   'Number',
#   'Person',
#   'Poss',
#   'PronType',
#   'Tense',
#   'VerbForm',
#   'Voice',
#   'upos'])

# %%
results = [pattern1.findall(x) for x in texts]
results = [[float(x) for x in res] for res in results]

# %%
rt.plot(results, m_labels, labels=labels, 
        saved_path = 'imgs/macros_multi', figsize=(25,10),fontsize_label=17 , fontsize_per=1)
#rt.plot(results, m_labels, labels=labels)
