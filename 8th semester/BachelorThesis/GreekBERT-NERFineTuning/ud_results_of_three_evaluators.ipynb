# %%
import result_transformation as rt

# %%
our_results = """{'Abbr-macro-f1': macro-f1: 0.9660,
 'Abbr-micro-f1': micro-f1: 0.9991,
 'Aspect-macro-f1': macro-f1: 0.9927,
 'Aspect-micro-f1': micro-f1: 0.9985,
 'Case-macro-f1': macro-f1: 0.9874,
 'Case-micro-f1': micro-f1: 0.9842,
 'Definite-macro-f1': macro-f1: 0.9966,
 'Definite-micro-f1': micro-f1: 0.9997,
 'Degree-macro-f1': macro-f1: 0.7467,
 'Degree-micro-f1': micro-f1: 0.9994,
 'Foreign-macro-f1': macro-f1: 0.8847,
 'Foreign-micro-f1': micro-f1: 0.9946,
 'Gender-macro-f1': macro-f1: 0.9798,
 'Gender-micro-f1': micro-f1: 0.9862,
 'Mood-macro-f1': macro-f1: 0.9621,
 'Mood-micro-f1': micro-f1: 0.9995,
 'NumType-macro-f1': macro-f1: 0.9453,
 'NumType-micro-f1': micro-f1: 0.9973,
 'Number-macro-f1': macro-f1: 0.9923,
 'Number-micro-f1': micro-f1: 0.9919,
 'Person-macro-f1': macro-f1: 0.9976,
 'Person-micro-f1': micro-f1: 0.9989,
 'Poss-macro-f1': macro-f1: 0.9950,
 'Poss-micro-f1': micro-f1: 0.9998,
 'PronType-macro-f1': macro-f1: 0.9748,
 'PronType-micro-f1': micro-f1: 0.9989,
 'Tense-macro-f1': macro-f1: 0.9962,
 'Tense-micro-f1': micro-f1: 0.9993,
 'VerbForm-macro-f1': macro-f1: 0.9584,
 'VerbForm-micro-f1': micro-f1: 0.9990,
 'Voice-macro-f1': macro-f1: 0.9743,
 'Voice-micro-f1': micro-f1: 0.9960,
 'upos-macro-f1': macro-f1: 0.9655,
 'upos-micro-f1': micro-f1: 0.9830}
"""

our_results_excluding_underscor = """{'Abbr-macro-f1': macro-f1: 0.9459,
 'Abbr-micro-f1': micro-f1: 0.9459,
 'Aspect-macro-f1': macro-f1: 0.9808,
 'Aspect-micro-f1': micro-f1: 0.9822,
 'Case-macro-f1': macro-f1: 0.9860,
 'Case-micro-f1': micro-f1: 0.9760,
 'Definite-macro-f1': macro-f1: 0.9949,
 'Definite-micro-f1': micro-f1: 0.9988,
 'Degree-macro-f1': macro-f1: 0.4951,
 'Degree-micro-f1': micro-f1: 0.9273,
 'Foreign-macro-f1': macro-f1: 0.7891,
 'Foreign-micro-f1': micro-f1: 0.7891,
 'Gender-macro-f1': macro-f1: 0.9726,
 'Gender-micro-f1': micro-f1: 0.9774,
 'Mood-macro-f1': macro-f1: 0.5881,
 'Mood-micro-f1': micro-f1: 0.9902,
 'NumType-macro-f1': macro-f1: 0.6891,
 'NumType-micro-f1': micro-f1: 0.8930,
 'Number-macro-f1': macro-f1: 0.9925,
 'Number-micro-f1': micro-f1: 0.9919,
 'Person-macro-f1': macro-f1: 0.9961,
 'Person-micro-f1': micro-f1: 0.9952,
 'Poss-macro-f1': macro-f1: 0.9754,
 'Poss-micro-f1': micro-f1: 0.9754,
 'PronType-macro-f1': macro-f1: 0.9149,
 'PronType-micro-f1': micro-f1: 0.9944,
 'Tense-macro-f1': macro-f1: 0.9960,
 'Tense-micro-f1': micro-f1: 0.9953,
 'VerbForm-macro-f1': macro-f1: 0.9184,
 'VerbForm-micro-f1': micro-f1: 0.9922,
 'Voice-macro-f1': macro-f1: 0.9517,
 'Voice-micro-f1': micro-f1: 0.9571,
 'upos-macro-f1': macro-f1: 0.9646,
 'upos-micro-f1': micro-f1: 0.9808}
"""

our_results_using_rules = """{'Abbr-macro-f1': macro-f1: 0.9371,
 'Abbr-micro-f1': micro-f1: 0.9371,
 'Aspect-macro-f1': macro-f1: 0.9855,
 'Aspect-micro-f1': micro-f1: 0.9866,
 'Case-macro-f1': macro-f1: 0.9684,
 'Case-micro-f1': micro-f1: 0.9767,
 'Definite-macro-f1': macro-f1: 1.0000,
 'Definite-micro-f1': micro-f1: 1.0000,
 'Degree-macro-f1': macro-f1: 0.4904,
 'Degree-micro-f1': micro-f1: 0.9189,
 'Foreign-macro-f1': macro-f1: 0.8761,
 'Foreign-micro-f1': micro-f1: 0.8761,
 'Gender-macro-f1': macro-f1: 0.9775,
 'Gender-micro-f1': micro-f1: 0.9822,
 'Mood-macro-f1': macro-f1: 0.8315,
 'Mood-micro-f1': micro-f1: 0.9940,
 'NumType-macro-f1': macro-f1: 0.9437,
 'NumType-micro-f1': micro-f1: 0.9584,
 'Number-macro-f1': macro-f1: 0.9945,
 'Number-micro-f1': micro-f1: 0.9945,
 'Person-macro-f1': macro-f1: 0.9972,
 'Person-micro-f1': micro-f1: 0.9961,
 'Poss-macro-f1': macro-f1: 0.9802,
 'Poss-micro-f1': micro-f1: 0.9802,
 'PronType-macro-f1': macro-f1: 0.9735,
 'PronType-micro-f1': micro-f1: 0.9972,
 'Tense-macro-f1': macro-f1: 0.9957,
 'Tense-micro-f1': micro-f1: 0.9959,
 'VerbForm-macro-f1': macro-f1: 0.9327,
 'VerbForm-micro-f1': micro-f1: 0.9939,
 'Voice-macro-f1': macro-f1: 0.9572,
 'Voice-micro-f1': micro-f1: 0.9618,
 'upos-macro-f1': macro-f1: 0.9637,
 'upos-micro-f1': micro-f1: 0.9816}"""

# %%
f1,labels= rt.get_final_results_our_type_mtask(our_results,getLabels=True)
f1_excluding_underscor = rt.get_final_results_our_type_mtask(our_results_excluding_underscor)
f1_using_rules = rt.get_final_results_our_type_mtask(our_results_using_rules)

#all
rt.plot([f1, f1_excluding_underscor, f1_using_rules], ['1','2','3'], labels=labels, saved_path = 'imgs/f1_ud_all', figsize=(30,10))

# %%
f1_mic,f1_mac,labels= rt.get_final_results_seperated_our_type_mtask(our_results,getLabels=True)
f1_excluding_underscor_mic,f1_excluding_underscor_mac = rt.get_final_results_seperated_our_type_mtask(our_results_excluding_underscor)
f1_using_rules_mic, f1_using_rules_mac = rt.get_final_results_seperated_our_type_mtask(our_results_using_rules)

# micro
rt.plot([f1_mic, f1_excluding_underscor_mic, f1_using_rules_mic], ['1','2','3'], labels=labels, 
        saved_path = 'imgs/micros_ud', figsize=(25,10),fontsize_label=23,fontsize_per=10)

# %%
# macro
rt.plot([f1_mac, f1_excluding_underscor_mac, f1_using_rules_mac], ['1','2','3'], labels=labels, 
        saved_path = 'imgs/macros_ud', figsize=(25,10),fontsize_label=23,fontsize_per=10)
