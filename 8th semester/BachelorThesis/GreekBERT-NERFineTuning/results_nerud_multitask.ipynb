         ORG       0.77      0.89      0.82      1388
     PERCENT       0.93      1.00      0.96       206
      PERSON       0.94      0.96      0.95      1051
     PRODUCT       0.52      0.46      0.49        83
    QUANTITY       0.63      0.86      0.73        65
        TIME       0.79      0.90      0.84       137
 WORK_OF_ART       0.56      0.52      0.54        84
   micro avg       0.82      0.89      0.85      6435
   macro avg       0.69      0.71      0.69      6435
   weighted avg       0.82      0.89      0.85      6435
"""

# %%
#cls_reports = [ner_no_multitask , interleaving_best_both, interleaving_best_ner, interleaving_best_ud]
#cls_reports += [oversampling_best_both, oversampling_best_ner, oversampling_best_ud]
cls_reports = [ner_no_multitask, interleaving_best_both, interleaving_best_ner]

# %%
import re
def classification_report_formatted(report):
    formatted = [x.split(' ') for x in report.split('\n')  if len(x) > 0] 
    non_zero = [[y for y in x if len(y)> 0] for x in formatted]
    return non_zero[1:][:-3]
def labels(formatted):
    return [x[0] for x in formatted]
def f1_scores(formatted):
    return [float(x[3]) for x in formatted]
    
classification_report_formatted(oversampling_best_both)
# Out:
# [['CARDINAL', '0.90', '0.94', '0.92', '911'],
#  ['DATE', '0.85', '0.91', '0.88', '838'],
#  ['EVENT', '0.51', '0.48', '0.49', '130'],
#  ['FAC', '0.34', '0.27', '0.30', '77'],
#  ['GPE', '0.82', '0.95', '0.88', '826'],
#  ['LANGUAGE', '0.00', '0.00', '0.00', '9'],
#  ['LAW', '0.60', '0.32', '0.42', '28'],
#  ['LOC', '0.64', '0.57', '0.60', '178'],
#  ['MONEY', '0.89', '0.97', '0.93', '111'],
#  ['NORP', '0.76', '0.91', '0.83', '141'],
#  ['ORDINAL', '0.95', '0.91', '0.93', '172'],
#  ['ORG', '0.77', '0.89', '0.82', '1388'],
#  ['PERCENT', '0.93', '1.00', '0.96', '206'],
#  ['PERSON', '0.94', '0.96', '0.95', '1051'],
#  ['PRODUCT', '0.52', '0.46', '0.49', '83'],
#  ['QUANTITY', '0.63', '0.86', '0.73', '65'],
#  ['TIME', '0.79', '0.90', '0.84', '137'],
#  ['WORK_OF_ART', '0.56', '0.52', '0.54', '84']]

# %%
m_scores = []
per_labels= None 
for cls_report in cls_reports:
    m_scores.append(f1_scores(classification_report_formatted(cls_report)))
    per_labels = labels(classification_report_formatted(cls_report))
    
#m_labels = ['separate' , 'interleaving_best_both', 'interleaving_best_ner' , 'interleaving_best_ud']
#m_labels += ['oversampling_best_both', 'oversampling_best_ner', 'oversampling_best_ud']
m_labels = ['ner_no_multitask', 'interleaving_best_both', 'interleaving_best_ner']

# %%
for i ,j in zip(m_scores, m_labels):
    print(len(i) , j)
# Out:
# 18 ner_no_multitask
# 18 interleaving_best_both
# 18 interleaving_best_ner

# %%
from result_transformation import plot
plot(m_scores,m_labels, labels=per_labels, fontsize_label=8, fontsize_per=8,figsize=(17, 10))

# %%
m_scores = [
    [0.91, 0.86],
    [0.90, 0.85],
    [0.91, 0.86],
    [0.91, 0.84],
    [0.85, 0.69],
]
m_labels = ['separate' , 'interleaving_best_both', 'interleaving_best_ner' , 'interleaving_best_ud', 'oversampling']
per_labels = ['micro-f1' , 'macro-f1']

# %%
plot(m_scores,m_labels, labels=per_labels, fontsize_label=16, fontsize_per=16,figsize=(24, 7), width= 0.1)

# %%
total_results = []

# %%
total_results
# Out:
# [{('Abbr', 'macro'): 0.9371,
#   ('Abbr', 'micro'): 0.9371,
#   ('Aspect', 'macro'): 0.9855,
#   ('Aspect', 'micro'): 0.9866,
#   ('Case', 'macro'): 0.9684,
#   ('Case', 'micro'): 0.9767,
#   ('Degree', 'macro'): 0.4904,
#   ('Degree', 'micro'): 0.9189,
#   ('Foreign', 'macro'): 0.8761,
#   ('Foreign', 'micro'): 0.8761,
#   ('Gender', 'macro'): 0.9775,
#   ('Gender', 'micro'): 0.9822,
#   ('Mood', 'macro'): 0.8315,
#   ('Mood', 'micro'): 0.994,
#   ('NumType', 'macro'): 0.9437,
#   ('NumType', 'micro'): 0.9584,
#   ('Number', 'macro'): 0.9945,
#   ('Number', 'micro'): 0.9945,
#   ('Person', 'macro'): 0.9972,
#   ('Person', 'micro'): 0.9961,
#   ('Poss', 'macro'): 0.9802,
#   ('Poss', 'micro'): 0.9802,
#   ('PronType', 'macro'): 0.9735,
#   ('PronType', 'micro'): 0.9972,
#   ('Tense', 'macro'): 0.9957,
#   ('Tense', 'micro'): 0.9959,
#   ('VerbForm', 'macro'): 0.9327,
#   ('VerbForm', 'micro'): 0.9939,
#   ('Voice', 'macro'): 0.9572,
#   ('Voice', 'micro'): 0.9618,
# ...

# %%
# Separate
data = """
{'Abbr-macro-f1': macro-f1: 0.9371,
 'Abbr-micro-f1': micro-f1: 0.9371,
 'Aspect-macro-f1': macro-f1: 0.9855,
 'Aspect-micro-f1': micro-f1: 0.9866,
 'Case-macro-f1': macro-f1: 0.9684,
 'Case-micro-f1': micro-f1: 0.9767,
 'Definite-macro-f1': macro-f1: 1.0000,
 'Definite-micro-f1': micro-f1: 1.0000,
 'Degree-macro-f1': macro-f1: 0.4904,
 'Degree-micro-f1': micro-f1: 0.9189,
 'Foreign-macro-f1': macro-f1: 0.8761,
 'Foreign-micro-f1': micro-f1: 0.8761,
 'Gender-macro-f1': macro-f1: 0.9775,
 'Gender-micro-f1': micro-f1: 0.9822,
 'Mood-macro-f1': macro-f1: 0.8315,
 'Mood-micro-f1': micro-f1: 0.9940,
 'NumType-macro-f1': macro-f1: 0.9437,
 'NumType-micro-f1': micro-f1: 0.9584,
 'Number-macro-f1': macro-f1: 0.9945,
 'Number-micro-f1': micro-f1: 0.9945,
 'Person-macro-f1': macro-f1: 0.9972,
 'Person-micro-f1': micro-f1: 0.9961,
 'Poss-macro-f1': macro-f1: 0.9802,
 'Poss-micro-f1': micro-f1: 0.9802,
 'PronType-macro-f1': macro-f1: 0.9735,
 'PronType-micro-f1': micro-f1: 0.9972,
 'Tense-macro-f1': macro-f1: 0.9957,
 'Tense-micro-f1': micro-f1: 0.9959,
 'VerbForm-macro-f1': macro-f1: 0.9327,
 'VerbForm-micro-f1': micro-f1: 0.9939,
 'Voice-macro-f1': macro-f1: 0.9572,
 'Voice-micro-f1': micro-f1: 0.9618,
 'total-acc': acc: 0.9953,
 'upos-macro-f1': macro-f1: 0.9637,
 'upos-micro-f1': micro-f1: 0.9816}
"""

import re
patt = re.compile("(\\w*)-(micro|macro)-.*(0.\\d\\d\\d\\d)")
occ = patt.findall(data)
summary =  {(x[0],x[1]) : float(x[2]) for x in occ}
summary['name'] = 'separate'
total_results.append(summary)

# %%
# Interlevaign-bst-ner
data = """
ud-Case-macro-f1:macro-f1: 0.9825
ud-Case-micro-f1:micro-f1: 0.9790
ud-Definite-macro-f1:macro-f1: 1.0000
ud-Definite-micro-f1:micro-f1: 1.0000
ud-Gender-macro-f1:macro-f1: 0.9753
ud-Gender-micro-f1:micro-f1: 0.9794
ud-Number-macro-f1:macro-f1: 0.9933
ud-Number-micro-f1:micro-f1: 0.9939
ud-PronType-macro-f1:macro-f1: 0.9702
ud-PronType-micro-f1:micro-f1: 0.9962
ud-Foreign-macro-f1:macro-f1: 0.6907
ud-Foreign-micro-f1:micro-f1: 0.6907
ud-Aspect-macro-f1:macro-f1: 0.9865
ud-Aspect-micro-f1:micro-f1: 0.9874
ud-Mood-macro-f1:macro-f1: 0.9106
ud-Mood-micro-f1:micro-f1: 0.9963
ud-Person-macro-f1:macro-f1: 0.9977
ud-Person-micro-f1:micro-f1: 0.9958
ud-Tense-macro-f1:macro-f1: 0.9974
ud-Tense-micro-f1:micro-f1: 0.9971
ud-VerbForm-macro-f1:macro-f1: 0.9410
ud-VerbForm-micro-f1:micro-f1: 0.9948
ud-Voice-macro-f1:macro-f1: 0.9541
ud-Voice-micro-f1:micro-f1: 0.9593
ud-NumType-macro-f1:macro-f1: 0.9101
ud-NumType-micro-f1:micro-f1: 0.9448
ud-Poss-macro-f1:macro-f1: 0.9751
ud-Poss-micro-f1:micro-f1: 0.9751
ud-Degree-macro-f1:macro-f1: 0.8588
ud-Degree-micro-f1:micro-f1: 0.9649
ud-Abbr-macro-f1:macro-f1: 0.8000
ud-Abbr-micro-f1:micro-f1: 0.8000
ud-upos-macro-f1:macro-f1: 0.9560
ud-upos-micro-f1:micro-f1: 0.9784
"""

import re
patt = re.compile("(\\w*)-(micro|macro)-.*(0.\\d\\d\\d\\d)")
occ = patt.findall(data)
summary =  {(x[0],x[1]) : float(x[2]) for x in occ}
summary['name'] = 'interleaving-best-ner'
total_results.append(summary)

# %%
# Interlevaign-bst-ud
data = """
ud-Case-macro-f1:macro-f1: 0.9817
ud-Case-micro-f1:micro-f1: 0.9778
ud-Definite-macro-f1:macro-f1: 1.0000
ud-Definite-micro-f1:micro-f1: 1.0000
ud-Gender-macro-f1:macro-f1: 0.9714
ud-Gender-micro-f1:micro-f1: 0.9770
ud-Number-macro-f1:macro-f1: 0.9921
ud-Number-micro-f1:micro-f1: 0.9923
ud-PronType-macro-f1:macro-f1: 0.9721
ud-PronType-micro-f1:micro-f1: 0.9967
ud-Foreign-macro-f1:macro-f1: 0.8908
ud-Foreign-micro-f1:micro-f1: 0.8908
ud-Aspect-macro-f1:macro-f1: 0.9852
ud-Aspect-micro-f1:micro-f1: 0.9861
ud-Mood-macro-f1:macro-f1: 0.9727
ud-Mood-micro-f1:micro-f1: 0.9977
ud-Person-macro-f1:macro-f1: 0.9917
ud-Person-micro-f1:micro-f1: 0.9961
ud-Tense-macro-f1:macro-f1: 0.9952
ud-Tense-micro-f1:micro-f1: 0.9942
ud-VerbForm-macro-f1:macro-f1: 0.9241
ud-VerbForm-micro-f1:micro-f1: 0.9935
ud-Voice-macro-f1:macro-f1: 0.9565
ud-Voice-micro-f1:micro-f1: 0.9614
ud-NumType-macro-f1:macro-f1: 0.8524
ud-NumType-micro-f1:micro-f1: 0.9174
ud-Poss-macro-f1:macro-f1: 0.9800
ud-Poss-micro-f1:micro-f1: 0.9800
ud-Degree-macro-f1:macro-f1: 0.8588
ud-Degree-micro-f1:micro-f1: 0.9649
ud-Abbr-macro-f1:macro-f1: 0.8421
ud-Abbr-micro-f1:micro-f1: 0.8421
ud-upos-macro-f1:macro-f1: 0.9657
ud-upos-micro-f1:micro-f1: 0.9809
"""

import re
patt = re.compile("(\\w*)-(micro|macro)-.*(0.\\d\\d\\d\\d)")
occ = patt.findall(data)
summary =  {(x[0],x[1]) : float(x[2]) for x in occ}
summary['name'] = 'interleaving-best-ud'
total_results.append(summary)

# %%
# Interlevaign-bst-both
data = """
ud-Case-macro-f1:macro-f1: 0.9817
ud-Case-micro-f1:micro-f1: 0.9778
ud-Definite-macro-f1:macro-f1: 0.9948
ud-Definite-micro-f1:micro-f1: 0.9988
ud-Gender-macro-f1:macro-f1: 0.9699
ud-Gender-micro-f1:micro-f1: 0.9756
ud-Number-macro-f1:macro-f1: 0.9929
ud-Number-micro-f1:micro-f1: 0.9934
ud-PronType-macro-f1:macro-f1: 0.9822
ud-PronType-micro-f1:micro-f1: 0.9977
ud-Foreign-macro-f1:macro-f1: 0.7905
ud-Foreign-micro-f1:micro-f1: 0.7905
ud-Aspect-macro-f1:macro-f1: 0.9756
ud-Aspect-micro-f1:micro-f1: 0.9770
ud-Mood-macro-f1:macro-f1: 0.9727
ud-Mood-micro-f1:micro-f1: 0.9977
ud-Person-macro-f1:macro-f1: 0.9908
ud-Person-micro-f1:micro-f1: 0.9955
ud-Tense-macro-f1:macro-f1: 0.9911
ud-Tense-micro-f1:micro-f1: 0.9895
ud-VerbForm-macro-f1:macro-f1: 0.9241
ud-VerbForm-micro-f1:micro-f1: 0.9935
ud-Voice-macro-f1:macro-f1: 0.9574
ud-Voice-micro-f1:micro-f1: 0.9623
ud-NumType-macro-f1:macro-f1: 0.9120
ud-NumType-micro-f1:micro-f1: 0.9408
ud-Poss-macro-f1:macro-f1: 0.9851
ud-Poss-micro-f1:micro-f1: 0.9851
ud-Degree-macro-f1:macro-f1: 0.6152
ud-Degree-micro-f1:micro-f1: 0.9273
ud-Abbr-macro-f1:macro-f1: 0.8794
ud-Abbr-micro-f1:micro-f1: 0.8794
ud-upos-macro-f1:macro-f1: 0.9588
ud-upos-micro-f1:micro-f1: 0.9789

"""

import re
patt = re.compile("(\\w*)-(micro|macro)-.*(0.\\d\\d\\d\\d)")
occ = patt.findall(data)
summary =  {(x[0],x[1]) : float(x[2]) for x in occ}
summary['name'] = 'interleaving-best-both'
total_results.append(summary)

# %%
# Oversampling res
data = """
ud-Case-macro-f1:macro-f1: 0.9634
ud-Case-micro-f1:micro-f1: 0.9756
ud-Definite-macro-f1:macro-f1: 1.0000
ud-Definite-micro-f1:micro-f1: 1.0000
ud-Gender-macro-f1:macro-f1: 0.9700
ud-Gender-micro-f1:micro-f1: 0.9756
ud-Number-macro-f1:macro-f1: 0.9917
ud-Number-micro-f1:micro-f1: 0.9920
ud-PronType-macro-f1:macro-f1: 0.9473
ud-PronType-micro-f1:micro-f1: 0.9960
ud-Foreign-macro-f1:macro-f1: 0.8186
ud-Foreign-micro-f1:micro-f1: 0.8186
ud-Aspect-macro-f1:macro-f1: 0.9814
ud-Aspect-micro-f1:micro-f1: 0.9826
ud-Mood-macro-f1:macro-f1: 0.6641
ud-Mood-micro-f1:micro-f1: 0.9912
ud-Person-macro-f1:macro-f1: 0.9908
ud-Person-micro-f1:micro-f1: 0.9955
ud-Tense-macro-f1:macro-f1: 0.9919
ud-Tense-micro-f1:micro-f1: 0.9925
ud-VerbForm-macro-f1:macro-f1: 0.8994
ud-VerbForm-micro-f1:micro-f1: 0.9922
ud-Voice-macro-f1:macro-f1: 0.9528
ud-Voice-micro-f1:micro-f1: 0.9583
ud-NumType-macro-f1:macro-f1: 0.7038
ud-NumType-micro-f1:micro-f1: 0.9307
ud-Poss-macro-f1:macro-f1: 0.9751
ud-Poss-micro-f1:micro-f1: 0.9751
ud-Degree-macro-f1:macro-f1: 0.4808
ud-Degree-micro-f1:micro-f1: 0.9009
ud-Abbr-macro-f1:macro-f1: 0.9371
ud-Abbr-micro-f1:micro-f1: 0.9371
ud-upos-macro-f1:macro-f1: 0.9613
ud-upos-micro-f1:micro-f1: 0.9794
"""

import re
patt = re.compile("(\\w*)-(micro|macro)-.*(0.\\d\\d\\d\\d)")
occ = patt.findall(data)
summary =  {(x[0],x[1]) : float(x[2]) for x in occ}
summary['name'] = 'oversampling'
total_results.append(summary)

# %%
labels_per = set(labels_per)
labels_per
# Out:
# {'Abbr',
#  'Aspect',
#  'Case',
#  'Degree',
#  'Foreign',
#  'Gender',
#  'Mood',
#  'NumType',
#  'Number',
#  'Person',
#  'Poss',
#  'PronType',
#  'Tense',
#  'VerbForm',
#  'Voice',
#  'upos'}

# %%
from result_transformation import plot
avg = 'micro'
m_scores = []
m_labels = []
for summary in total_results:
    curr_scores = [summary[(x,avg)] for x in labels_per]
    m_scores.append(curr_scores)
    m_labels.append(summary['name'])

plot(m_scores,m_labels, labels=labels_per, fontsize_label=8, fontsize_per=3,figsize=(17, 10), width= 0.1)

# %%
from result_transformation import plot
avg = 'macro'
m_scores = []
m_labels = []
for summary in total_results:
    curr_scores = [summary[(x,avg)] for x in labels_per]
    m_scores.append(curr_scores)
    m_labels.append(summary['name'])

plot(m_scores,m_labels, labels=labels_per, fontsize_label=8, fontsize_per=3,figsize=(17, 10), width= 0.1)
